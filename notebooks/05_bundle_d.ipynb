# %% [markdown]
# # Bundle D
#
# Bundle D uses PnP-ADMM for additive cleanup and then a Speckle2Void-style wrapper with an honest blind-spot fallback when no external backend is configured.

# %%
# !python scripts/run_bundle_d.py --config configs/bundle_d.yaml
