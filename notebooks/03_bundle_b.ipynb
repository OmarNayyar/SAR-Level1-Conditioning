# %% [markdown]
# # Bundle B
#
# Bundle B targets structured additive artifacts first and then runs a MuLoG-style log-domain speckle suppression path.

# %%
# !python scripts/run_bundle_b.py --config configs/bundle_b.yaml
