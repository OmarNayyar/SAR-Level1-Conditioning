# %% [markdown]
# # Comparison Pack
#
# Run the comparison-pack export after one or more bundles have completed.

# %%
# !python scripts/export_figures.py --bundles bundle_a bundle_b bundle_c bundle_d

# %%
from pathlib import Path
import json

comparison = json.loads(Path('results/comparison_tables/bundle_comparison.json').read_text(encoding='utf-8'))
comparison
