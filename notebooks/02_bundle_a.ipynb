# %% [markdown]
# # Bundle A
#
# Bundle A is the main practical baseline: metadata-driven thermal subtraction in the intensity domain followed by Refined Lee. Use SSDD or HRSID first, then Sentinel-1 for proxy and metadata checks.

# %%
# !python scripts/run_bundle_a.py --config configs/bundle_a.yaml

# %%
from pathlib import Path
import json

summary = json.loads(Path('results/bundle_a/run_summary.json').read_text(encoding='utf-8'))
summary
