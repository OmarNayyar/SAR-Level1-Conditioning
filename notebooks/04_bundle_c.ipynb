# %% [markdown]
# # Bundle C
#
# Bundle C is the feasibility path. It prefers complex SLC-like inputs, but the current config allows a detected-domain fallback so the path remains runnable while SLC coverage is limited.

# %%
# !python scripts/run_bundle_c.py --config configs/bundle_c.yaml
